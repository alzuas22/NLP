# %% [markdown]
# **4. Reporte de métricas y conclusiones**
#
#
# ---
#
# 1. **Desempeño General:**
#    - **Logistic Regression:** En ambos escenarios (CountVectorizer y TfidfVectorizer), vemos que nuestra regresión logística muestra un desempeño equilibrado con una alta precisión y recall para las reviews positivas, lo que indica que nuestro modelo es efectivo en identificar correctamente las reseñas positivas.
#    - **Random Forest:** Aunque nuestro modelo de Random Forest tiene un recall muy alto (casi perfecto) para las reviews positivas, su precisión es menor que la de la regresión logística y su desempeño en las reviews negativas es peor, sobretodo en el recall.
#
# 2. **Reviews negativas (0):**
#    - **Logistic Regression:** El desempeño en las reviews negativas es moderado, con un recall que varía entre 0.41 y 0.50. Esto sugiere que nuestro modelo identifica algunas reseñas negativas correctamente, pero también tiene una cantidad significativa de falsos positivos.
#    - **Random Forest:** Nuestro modelo tiene una precisión alta (0.92 a 0.95), pero un recall extremadamente bajo (0.05 a 0.06), lo que indica que casi no identifica correctamente las reseñas negativas.
#
# 3. **Reviews positivas (1):**
#    - **Logistic Regression:** Lo hace de forma excelente con alta precisión (0.87 a 0.88) y recall (0.96), lo que indica que nuestro modelo identifica correctamente la mayoría de las reseñas positivas y tiene pocos falsos negativos.
#    - **Random Forest:** Tiene un recall perfecto (1.00), pero una precisión menor (0.80 a 0.81), lo que indica que aunque detecta todas las reseñas positivas, tiene más falsos positivos que la regresión logística.
#
# 4. **Weighted Averages:**
#    - **Logistic Regression:** Los promedios macro y ponderados son más equilibrados, con un F1-score promedio ponderado de 0.83 a 0.86, lo que sugiere un buen desempeño global de nuestro modelo.
#    - **Random Forest:** Los promedios macro muestran un desequilibrio significativo, especialmente en recall (0.52 a 0.53) y F1-score (0.49 a 0.50), indicando que nuestro modelo no maneja bien las clases de manera equilibrada.
#
# 5. **Efecto del Vectorizador:**
#    - **TfidfVectorizer:** Utilizar TfidfVectorizer parece mejorar ligeramente el desempeño de nuestra regresión logística, aumentando tanto la precisión como el recall y el F1-score.
#    - **CountVectorizer:** Aunque produce buenos resultados, nuestro modelo parece beneficiarse más del TfidfVectorizer en términos de métricas de desempeño.
#
# Como conclusiones: nuestra regresión logística muestra un desempeño superior y más equilibrado en la clasificación de sentimientos, especialmente cuando se utiliza TfidfVectorizer, lo que sugiere que es el mejor modelo de machine learning para este conjunto de datos.
